# %%
import pandas as pd

# %%
path = "Defense/defense.csv"
data = pd.read_csv(path,encoding="ISO-8859-1")
data.head()
# Out:
#    Rk  Year                   Player  Pos    AV              School  \
# 0   1  2000     Brian Young\YounBr20   DE  47.0       Texas-El Paso
# 1   2  2000  Cedric Woodard\WoodCe20   DT  15.0               Texas
# 2   3  2000  Antonio Wilson\WilsAn20  OLB   2.0  Texas A&M-Commerce
# 3   4  2000   Josh Williams\WillJo30   DT  19.0            Michigan
# 4   5  2000   Damen Wheeler\WheeDa20   CB   0.0            Colorado
#
#          College Height   Wt  40YD  Vertical  BenchReps  Broad Jump  3Cone  \
# 0  College Stats  2-Jun  278  4.94      29.5       27.0       106.0   7.20
# 1            NaN  2-Jun  290  5.21      30.5       23.0       109.0    NaN
# 2            NaN  2-Jun  245  4.56       NaN       11.0         NaN    NaN
# 3            NaN  3-Jun  282  4.90      30.5        NaN       111.0   7.22
# 4            NaN  9-May  179  4.51      35.0       11.0       115.0   7.21
#
#    Shuttle                                       Drafted
# ...

# %%
new = data["Drafted"]= data["Drafted"].str.split("/", n = 3, expand = True)
data["Round"] = new[1]
data["Pick"] = new[2]
data.head()
# Out:
#    Rk  Year                   Player  Pos    AV              School  \
# 0   1  2000     Brian Young\YounBr20   DE  47.0       Texas-El Paso
# 1   2  2000  Cedric Woodard\WoodCe20   DT  15.0               Texas
# 2   3  2000  Antonio Wilson\WilsAn20  OLB   2.0  Texas A&M-Commerce
# 3   4  2000   Josh Williams\WillJo30   DT  19.0            Michigan
# 4   5  2000   Damen Wheeler\WheeDa20   CB   0.0            Colorado
#
#          College Height   Wt  40YD  Vertical  BenchReps  Broad Jump  3Cone  \
# 0  College Stats  2-Jun  278  4.94      29.5       27.0       106.0   7.20
# 1            NaN  2-Jun  290  5.21      30.5       23.0       109.0    NaN
# 2            NaN  2-Jun  245  4.56       NaN       11.0         NaN    NaN
# 3            NaN  3-Jun  282  4.90      30.5        NaN       111.0   7.22
# 4            NaN  9-May  179  4.51      35.0       11.0       115.0   7.21
#
#    Shuttle              Drafted  Round          Pick
# ...

# %%
import re
r = re.compile("([a-zA-Z]+)([0-9]+)")
strings = data['Round']
print (r.match(strings))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-d1390e0e233c> in <module>
#       2 r = re.compile("([a-zA-Z]+)([0-9]+)")
#       3 strings = data['Round']
# ----> 4 print (r.match(strings))
#
# TypeError: expected string or bytes-like object
