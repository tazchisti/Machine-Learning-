# %%
import pandas as pd

# %%
path = "Defense/defense.csv"
data = pd.read_csv(path,encoding="ISO-8859-1")

# %%
new = data["Drafted"]= data["Drafted"].str.split("/", n = 3, expand = True)
data["Round"] = new[1]
data["Pick"] = new[2]

# %%
new_1 = data["Round"]= data["Round"].str.split("th", n = 1, expand = True)
data["Round"] = new_1[0]

# %%
new_2 = data["Round"]= data["Round"].str.split("nd", n = 1, expand = True)
data["Round"] = new_2[0]

# %%
new_3 = data["Round"]= data["Round"].str.split("st", n = 1, expand = True)
data["Round"] = new_3[0]

# %%
new_4 = data["Round"]= data["Round"].str.split("rd", n = 1, expand = True)
data["Round"] = new_4[0]

# %%
data.drop(columns =["Pick"], inplace = True)

# %%
new = data["Player"]= data["Player"].str.split("\\", n = 1, expand = True)
data["Player"] = new[0]

data.head()
# Out:
#    Rk  Year          Player  Pos    AV              School        College  \
# 0   1  2000     Brian Young   DE  47.0       Texas-El Paso  College Stats
# 1   2  2000  Cedric Woodard   DT  15.0               Texas            NaN
# 2   3  2000  Antonio Wilson  OLB   2.0  Texas A&M-Commerce            NaN
# 3   4  2000   Josh Williams   DT  19.0            Michigan            NaN
# 4   5  2000   Damen Wheeler   CB   0.0            Colorado            NaN
#
#   Height   Wt  40YD  Vertical  BenchReps  Broad Jump  3Cone  Shuttle  \
# 0  2-Jun  278  4.94      29.5       27.0       106.0   7.20     4.47
# 1  2-Jun  290  5.21      30.5       23.0       109.0    NaN      NaN
# 2  2-Jun  245  4.56       NaN       11.0         NaN    NaN      NaN
# 3  3-Jun  282  4.90      30.5        NaN       111.0   7.22     4.25
# 4  9-May  179  4.51      35.0       11.0       115.0   7.21     4.27
#
#                Drafted Round
# 0      St. Louis Rams      5
# 1    Baltimore Ravens      6
# 2   Minnesota Vikings      4
# 3  Indianapolis Colts      4
# 4  San Diego Chargers      6

# %%
data.to_csv("Defense/clean_defense.csv", index=False, header=True)

# %%
path = "Offense/offense.csv"
data = pd.read_csv(path,encoding="ISO-8859-1")
data.head()
# Out:
#   Rk  Year                    Player Pos  AV       School        College  \
# 0  1  2000    Bashir Yamini\YamiBa20  WR   0         Iowa  College Stats
# 1  2  2000     Spergon Wynn\WynnSp00  QB   2  Texas State  College Stats
# 2  3  2000   James Williams\WillJa01  WR   4     Marshall  College Stats
# 3  4  2000  Bobbie Williams\WillBo21  OT  64     Arkansas            NaN
# 4  5  2000    Michael Wiley\WileMi00  RB   4   Ohio State  College Stats
#
#    Height   Wt  40YD Vertical BenchReps Broad Jump 3Cone Shuttle  \
# 0   3-Jun  191  4.53       33       NaN        130  7.09    4.18
# 1   3-Jun  229  4.91       34       NaN        108  7.71    4.59
# 2  11-May  180  4.59       36       NaN        123  7.22    4.16
# 3   4-Jun  332  5.26       29        28         97  7.78    4.72
# 4  11-May  193   4.5      NaN       NaN        NaN   NaN     NaN
#
#                                         Drafted
# 0                                           NaN
# 1    Cleveland Browns / 6th / 183rd pick / 2000
# 2    Seattle Seahawks / 6th / 175th pick / 2000
# 3  Philadelphia Eagles / 2nd / 61st pick / 2000
# 4      Dallas Cowboys / 5th / 144th pick / 2000

# %%
new = data["Drafted"]= data["Drafted"].str.split("/", n = 3, expand = True)
data["Round"] = new[1]
data["Pick"] = new[2]

# %%
new_1 = data["Round"]= data["Round"].str.split("th", n = 1, expand = True)
data["Round"] = new_1[0]

# %%
new_2 = data["Round"]= data["Round"].str.split("nd", n = 1, expand = True)
data["Round"] = new_2[0]

# %%
new_3 = data["Round"]= data["Round"].str.split("st", n = 1, expand = True)
data["Round"] = new_3[0]

# %%
new_4 = data["Round"]= data["Round"].str.split("rd", n = 1, expand = True)
data["Round"] = new_4[0]

# %%
new_5 = data["Player"]= data["Player"].str.split("\\", n = 1, expand = True)
data["Player"] = new_5[0]

# %%
data.drop(columns =["Pick"], inplace = True) 
data.head(50)
# Out:
#     Rk  Year              Player Pos  AV               School        College  \
# 0    1  2000       Bashir Yamini  WR   0                 Iowa  College Stats
# 1    2  2000        Spergon Wynn  QB   2          Texas State  College Stats
# 2    3  2000      James Williams  WR   4             Marshall  College Stats
# 3    4  2000     Bobbie Williams  OT  64             Arkansas            NaN
# 4    5  2000       Michael Wiley  RB   4           Ohio State  College Stats
# 5    6  2000           Dez White  WR  19         Georgia Tech  College Stats
# 6    7  2000     Austin Wheatley  TE   0                 Iowa  College Stats
# 7    8  2000        James Whalen  TE   1             Kentucky  College Stats
# 8    9  2000       Peter Warrick  WR  29        Florida State  College Stats
# 9   10  2000        Troy Walters  WR  13             Stanford  College Stats
# 10  11  2000           Todd Wade  OT  51          Mississippi            NaN
# 11  12  2000    Michael Thompson  OT   3      Tennessee State            NaN
# 12  13  2000        Jason Thomas  OG   1              Hampton            NaN
# 13  14  2000       Travis Taylor  WR  36              Florida  College Stats
# 14  15  2000       Mark Tauscher  OG  72            Wisconsin            NaN
# 15  16  2000            Jay Tant  TE   0         Northwestern  College Stats
# 16  17  2000       Shyrone Stith  RB   0        Virginia Tech  College Stats
# 17  18  2000     Dave Stachelski  TE   0          Boise State  College Stats
# 18  19  2000       R. Jay Soward  WR   2  Southern California  College Stats
# 19  20  2000      Terrelle Smith  FB   2        Arizona State  College Stats
# 20  21  2000          Paul Smith  FB   3        Texas-El Paso            NaN
# 21  22  2000        Marvel Smith  OT  57        Arizona State            NaN
# 22  23  2000         Wes Shivers  OT   0    Mississippi State            NaN
# 23  24  2000          Aaron Shea  FB   6             Michigan  College Stats
# 24  25  2000          Gari Scott  WR   0       Michigan State  College Stats
# 25  26  2000       Chris Samuels  OT  77              Alabama  College Stats
# 26  27  2000      Blaine Saipaia  OG   8       Colorado State            NaN
# 27  28  2000         Tutan Reyes  OT  21          Mississippi            NaN
# 28  29  2000        J.R. Redmond  RB   9        Arizona State  College Stats
# 29  30  2000        Chris Redman  QB  10           Louisville  College Stats
# 30  31  2000          Tim Rattay  QB  13       Louisiana Tech  College Stats
# 31  32  2000        Greg Randall  OT  20       Michigan State            NaN
# 32  33  2000     Travis Prentice  RB   4           Miami (OH)  College Stats
# 28  11-May  216  4.48     32.5       NaN        121   NaN     NaN
# 29   3-Jun  222  5.37     26.5       NaN         98   7.8    4.78
# 30  Jun-00  215  4.91     25.5       NaN        100  7.34    4.21
# 31   6-Jun  333  5.59       26        22         95  8.15    5.13
# 32  Jun-00  225   4.5       37        23        115  6.92     4.4
# 33   2-Jun  221  4.48      NaN       NaN        NaN   NaN     NaN
# 34   2-Jun  169  4.45      NaN       NaN        NaN   NaN     NaN
# 35   2-Jun  205  4.66     39.5       NaN        129  6.93    4.13
# 36   3-Jun  229  4.81     33.5       NaN        111  7.12    4.16
# 37  10-May  175  4.43     37.5       NaN        123  6.96    4.04
# 38   8-May  182   4.5       36        18        121   NaN     NaN
# 39   3-Jun  216   4.6     34.5       NaN        119  7.06    4.17
# 40  Jun-00  221  4.65     37.5        23        117  7.05    4.21
# 41   1-Jun  231  4.57       36        23        117   NaN     NaN
# 42  Jun-00  196  4.57       36       NaN        117  7.16    4.11
# 43  Jun-00  212  4.69       33       NaN        120  6.89    4.15
# 44   4-Jun  328  5.31       26        23         97  7.72    4.71
# 45   6-Jun  315  5.39      NaN        28        NaN   NaN     NaN
# 46   5-Jun  361   5.5      NaN        24        NaN   NaN     NaN
# 47  11-May  206  4.63       32       NaN        108  7.08    4.12
# 48   2-Jun  227  4.58     34.5       NaN        113   NaN     NaN
# 49  Jun-00  240  4.58      NaN        23        NaN   NaN     NaN
#
#                   Drafted Round
# 0                     NaN   NaN
# 1       Cleveland Browns      6
# 2       Seattle Seahawks      6
# 3    Philadelphia Eagles      2
# 4         Dallas Cowboys      5
# 5          Chicago Bears      3
# 6     New Orleans Saints      5
# 7   Tampa Bay Buccaneers      5
# 8     Cincinnati Bengals      1
# 9      Minnesota Vikings      5
# 10        Miami Dolphins      2
# 11       Atlanta Falcons      4
# 12    San Diego Chargers      7
# 13      Baltimore Ravens      1
# 14     Green Bay Packers      7
# 15     Arizona Cardinals      5
# 16  Jacksonville Jaguars      7
# 17  New England Patriots      5
# 18  Jacksonville Jaguars      1
# 19    New Orleans Saints      4
# 20   San Francisco 49ers      5
# 21   Pittsburgh Steelers      2
# 22      Tennessee Titans      7
# 23      Cleveland Browns      4
# 24   Philadelphia Eagles      4
# 25   Washington Redskins      1
# 26                    NaN   NaN
# 27    New Orleans Saints      5
# 28  New England Patriots      3
# 29      Baltimore Ravens      3
# 30   San Francisco 49ers      7
# 31  New England Patriots      4
# 32      Cleveland Browns      3
# 33       Oakland Raiders      2
# 34   Philadelphia Eagles      2
# 35       Atlanta Falcons      6
# 36         New York Jets      1
# 37      Cleveland Browns      2
# 38    New Orleans Saints      5
# 39    Kansas City Chiefs      1
# 40         Buffalo Bills      5
# 41    Kansas City Chiefs      4
# 42                    NaN   NaN
# 43     Green Bay Packers      7
# 44    San Diego Chargers      3
# 45      Seattle Seahawks      1
# 46         Detroit Lions      1
# 47                    NaN   NaN
# 48   Pittsburgh Steelers      5
# 49      Baltimore Ravens      1

# %%
data.to_csv("Offense/clean_offense.csv", index=False, header=True)
