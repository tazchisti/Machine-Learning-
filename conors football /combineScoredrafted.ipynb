# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
Offense = pd.read_csv('offensiveNFL_Data.csv')
Offense.set_index("Pos", inplace=True)
Offense
# Out:
#      Unnamed: 0  Year               Player  Height   Wt  40YD  Vertical  \
# Pos
# QB            0  2000         Spergon Wynn    75.0  229  4.91      34.0
# WR            1  2000       James Williams    71.0  180  4.59      36.0
# G             2  2000      Bobbie Williams    76.0  332  5.26      29.0
# RB            3  2000        Michael Wiley    71.0  193  4.50       0.0
# WR            4  2000            Dez White    73.0  218  4.62      37.5
# TE            5  2000      Austin Wheatley    76.0  254  4.66      32.5
# TE            6  2000         James Whalen    74.0  228  4.78      31.0
# WR            7  2000        Peter Warrick    71.0  194  4.58       0.0
# WR            8  2000         Troy Walters    66.0  171  4.55      32.5
# T             9  2000            Todd Wade    80.0  326  5.22      27.5
# T            10  2000     Michael Thompson    76.0  305  5.28      26.0
# G            11  2000         Jason Thomas    75.0  300  5.22      29.5
# ...

# %%
rb_df = Offense.loc["RB"]
rb_df
# Out:
#      Unnamed: 0  Year               Player  Height   Wt  40YD  Vertical  \
# Pos
# RB            3  2000        Michael Wiley    71.0  193  4.50       0.0
# RB           15  2000        Shyrone Stith    67.0  204  4.60      35.0
# RB           19  2000           Paul Smith    71.0  220  4.65       0.0
# RB           26  2000         J.R. Redmond    71.0  216  4.48      32.5
# RB           30  2000      Travis Prentice    73.0  225  4.50      37.0
# RB           36  2000          Chad Morton    68.0  182  4.50      36.0
# RB           38  2000         Sammy Morris    73.0  221  4.65      37.5
# RB           39  2000         Frank Moreau    73.0  231  4.57      36.0
# RB           40  2000       Rondell Mealey    73.0  212  4.69      33.0
# RB           45  2000          Jamal Lewis    73.0  240  4.58       0.0
# RB           49  2000        Curtis Keaton    70.0  214  4.41      41.5
# RB           51  2000         Thomas Jones    70.0  216  4.45       0.0
# ...

# %%
rb_df.to_csv("rb_df.csv", header=True, index=True)

# %%
X = Offense[["Height", "Wt", "40YD", "Vertical", "BenchReps", "3Cone", "Broad Jump", "Shuttle"]]
y = Offense["Round"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (1555, 8) (1555, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = model.predict(X_test_scaled)
model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), model.predict(X_train_scaled) - y_train_scaled, c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), model.predict(X_test_scaled) - y_test_scaled, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score


predicted = model.predict(X)


mse = mean_squared_error(y, predicted)
r2 = r2_score(y, predicted)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# Out:
# Mean Squared Error (MSE): 2107.0781351999904
# R-squared (R2 ): -534.5223996797731

# %%
model.score(X, y)
# Out:
# -534.5223996797731

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.score(X_test, y_test)
# Out:
# 0.05538695772835944

# %%
X = Offense.drop(columns=['Unnamed: 0', 'Year', 'Player', "AV", 'Round', "Rush Attempts", "Rush Yards", "Rush TDs", 'Drafted', 'Pick', 'Age', 'Team', 'All Pro', 'Pro Bowl', 'Games', 'Pass Completions', 'Interceptions', 'Pass Attempts', 'Pass Yards', 'Pass TDs', 'Receptions', 'Receiving Yards', 'Receiving TDs', 'Tackles', 'Picks', 'Sacks'])
y = Offense["Round"]
print(X.shape, y.shape)
# Out:
# (1555, 8) (1555,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.22469982847341338
# Testing Data Score: 0.17223650385604114

# %%
predictions = classifier.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   [4. 6. 4. 1. 1. 1. 6. 4. 3. 1.]
# First 10 Actual labels: [4.0, 7.0, 7.0, 3.0, 5.0, 1.0, 5.0, 1.0, 7.0, 4.0]

# %%
pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
# Out:
#      Prediction  Actual
# 0           4.0     4.0
# 1           6.0     7.0
# 2           4.0     7.0
# 3           1.0     3.0
# 4           1.0     5.0
# 5           1.0     1.0
# 6           6.0     5.0
# 7           4.0     1.0
# 8           3.0     7.0
# 9           1.0     4.0
# 10          6.0     5.0
# 11          3.0     1.0
# 12          7.0     4.0
# 13          5.0     5.0
# 14          4.0     4.0
# 15          6.0     7.0
# 16          1.0     4.0
# 17          4.0     7.0
# 18          4.0     2.0
# 19          6.0     3.0
# 20          6.0     2.0
# 21          4.0     6.0
# 22          1.0     2.0
# 23          1.0     3.0
# 24          1.0     3.0
# 25          1.0     1.0
# 26          1.0     3.0
# 27          7.0     1.0
# 28          4.0     2.0
# 29          1.0     1.0
# ..          ...     ...
# 359         6.0     4.0
# 360         7.0     4.0
# 361         1.0     7.0
# 362         1.0     7.0
# 363         6.0     3.0
# 364         6.0     2.0
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
target = rb_df["Round"]
target_names = ["1", "2", "3", "4", "5", "6", "7", "0"]

# %%
data = rb_df.drop(columns=['Unnamed: 0', 'Year', 'Player', "AV", "Rush Attempts", "Rush Yards", "Rush TDs", 'Drafted', 'Pick', 'Age', 'Team', 'All Pro', 'Pro Bowl', 'Games', 'Pass Completions', 'Interceptions', 'Pass Attempts', 'Pass Yards', 'Pass TDs', 'Receptions', 'Receiving Yards', 'Receiving TDs', 'Tackles', 'Picks', 'Sacks'])
feature_names = data.columns
data.head()
# Out:
#      Height   Wt  40YD  Vertical  BenchReps  Broad Jump  3Cone  Shuttle  Round
# Pos
# RB     71.0  193  4.50       0.0        0.0         0.0   0.00     0.00    5.0
# RB     67.0  204  4.60      35.0       13.0       111.0   7.14     4.14    7.0
# RB     71.0  220  4.65       0.0       25.0         0.0   0.00     0.00    5.0
# RB     71.0  216  4.48      32.5        0.0       121.0   0.00     0.00    3.0
# RB     73.0  225  4.50      37.0       23.0       115.0   6.92     4.40    3.0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
train_scores = []
test_scores = []
for k in range(1, 20, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    train_score = knn.score(X_train, y_train)
    test_score = knn.score(X_test, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(f"k: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")
    
    
plt.plot(range(1, 20, 2), train_scores, marker='o')
plt.plot(range(1, 20, 2), test_scores, marker="x")
plt.xlabel("k neighbors")
plt.ylabel("Testing accuracy Score")
plt.show()
# Out:
# k: 1, Train/Test Score: 1.000/0.300
# k: 3, Train/Test Score: 0.510/0.200
# k: 5, Train/Test Score: 0.486/0.171
# k: 7, Train/Test Score: 0.410/0.200
# k: 9, Train/Test Score: 0.371/0.186
# k: 11, Train/Test Score: 0.352/0.214
# k: 13, Train/Test Score: 0.376/0.200
# k: 15, Train/Test Score: 0.333/0.186
# k: 17, Train/Test Score: 0.290/0.157
# k: 19, Train/Test Score: 0.314/0.214

# %%
knn = KNeighborsClassifier(n_neighbors=13)
knn.fit(X_train, y_train)
print('k=13 Test Acc: %.3f' % knn.score(X_test, y_test))
# Out:
# k=13 Test Acc: 0.200

# %%
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
print('Test Acc: %.3f' % model.score(X_test, y_test))
# Out:
# Test Acc: 1.000

# %%
from sklearn.metrics import classification_report
predictions = model.predict(X_test)
print(classification_report(y_test, predictions,
                            target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#           1       1.00      1.00      1.00         9
#           2       1.00      1.00      1.00         9
#           3       1.00      1.00      1.00        10
#           4       1.00      1.00      1.00        14
#           5       1.00      1.00      1.00         7
#           6       1.00      1.00      1.00        12
#           7       1.00      1.00      1.00         9
#
# avg / total       1.00      1.00      1.00        70
# /Users/uknowconorhealy/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 7, does not match size of target_names, 8
#   .format(len(labels), len(target_names))
