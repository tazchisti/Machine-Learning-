# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
Offense = pd.read_csv('offensiveNFL_Data.csv')
Offense.set_index("Pos", inplace=True)
Offense.head()
# Out:
#      Unnamed: 0  Year           Player  Height   Wt  40YD  Vertical  \
# Pos
# QB            0  2000     Spergon Wynn      75  229  4.91      34.0
# WR            1  2000   James Williams      71  180  4.59      36.0
# G             2  2000  Bobbie Williams      76  332  5.26      29.0
# RB            3  2000    Michael Wiley      71  193  4.50       0.0
# WR            4  2000        Dez White      73  218  4.62      37.5
#
#      BenchReps  Broad Jump  3Cone  ...  Interceptions Rush Attempts  \
# Pos                                ...
# QB         0.0       108.0   7.71  ...            7.0          11.0
# WR         0.0       123.0   7.22  ...            0.0           1.0
# G         28.0        97.0   7.78  ...            0.0           0.0
# RB         0.0         0.0   0.00  ...            0.0          80.0
# WR         0.0       124.0   6.91  ...            0.0           8.0
#
#      Rush Yards Rush TDs  Receptions  Receiving Yards Receiving TDs  Tackles  \
# Pos
# ...

# %%
qb_df = Offense.loc["QB"]
qb_df.head()
# Out:
#      Unnamed: 0  Year           Player  Height   Wt  40YD  Vertical  \
# Pos
# QB            0  2000     Spergon Wynn      75  229  4.91      34.0
# QB           27  2000     Chris Redman      75  222  5.37      26.5
# QB           28  2000       Tim Rattay      73  215  4.91      25.5
# QB           34  2000  Chad Pennington      75  229  4.81      33.5
# QB           44  2000       Tee Martin      74  227  4.58      34.5
#
#      BenchReps  Broad Jump  3Cone  ...  Interceptions Rush Attempts  \
# Pos                                ...
# QB         0.0       108.0   7.71  ...            7.0          11.0
# QB         0.0        98.0   7.80  ...           14.0          33.0
# QB         0.0       100.0   7.34  ...           23.0          45.0
# QB         0.0       111.0   7.12  ...           64.0         180.0
# QB         0.0       113.0   0.00  ...            1.0           6.0
#
#      Rush Yards Rush TDs  Receptions  Receiving Yards Receiving TDs  Tackles  \
# Pos
# ...

# %%
qb_df.to_csv("qb_df.csv", header=True, index=True)

# %%
list(qb_df)
# Out:
# ['Unnamed: 0',
#  'Year',
#  'Player',
#  'Height',
#  'Wt',
#  '40YD',
#  'Vertical',
#  'BenchReps',
#  'Broad Jump',
#  '3Cone',
#  'Shuttle',
#  'Drafted',
#  'Round',
#  'Draft_Outcome',
#  'Pick',
#  'Age',
#  'Team',
#  'All Pro',
#  'Pro Bowl',
#  'AV',
#  'Games',
#  'Pass Completions',
#  'Pass Attempts',
#  'Pass Yards',
#  'Pass TDs',
#  'Interceptions',
#  'Rush Attempts',
#  'Rush Yards',
#  'Rush TDs',
#  'Receptions',
#  'Receiving Yards',
#  'Receiving TDs',
#  'Tackles',
#  'Picks',
#  'Sacks']

# %%
X = qb_df[["AV", "Pass Completions", "Pass Attempts", "Pass Yards", "Pass TDs", "Interceptions"]]
y = qb_df["Round"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (169, 6) (169, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)
# Out:
# /Users/uknowconorhealy/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)
# Out:
# /Users/uknowconorhealy/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = model.predict(X_test_scaled)
model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), model.predict(X_train_scaled) - y_train_scaled, c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), model.predict(X_test_scaled) - y_test_scaled, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score


predicted = model.predict(X)


mse = mean_squared_error(y, predicted)
r2 = r2_score(y, predicted)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# Out:
# Mean Squared Error (MSE): 578454166.6725796
# R-squared (R2 ): -125831931.84133217

# %%
model.score(X, y)
# Out:
# -125831931.84133218

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.score(X_test, y_test)
# Out:
# -0.11512822134736077

# %%
X = qb_df.drop(columns=['Unnamed: 0', 'Year', 'Player', 'Height', 'Wt', '40YD', 'Vertical', 'Draft_Outcome', 'Drafted', 'BenchReps', 'Broad Jump', '3Cone', 'Shuttle', 'Drafted', 'Pick', 'Age', 'Team', 'All Pro', 'Pro Bowl', 'Games', 'Rush Attempts', 'Rush Yards', 'Rush TDs', 'Receptions', 'Receiving Yards', 'Receiving TDs', 'Tackles', 'Picks', 'Sacks'])
y = qb_df["Round"]
print(X.shape, y.shape)
# Out:
# (169, 7) (169,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.5396825396825397
# Testing Data Score: 0.4883720930232558

# %%
predictions = classifier.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   [3 7 7 7 7 1 7 1 7 7]
# First 10 Actual labels: [1, 7, 7, 6, 7, 1, 7, 1, 6, 5]

# %%
pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
# Out:
#     Prediction  Actual
# 0            3       1
# 1            7       7
# 2            7       7
# 3            7       6
# 4            7       7
# 5            1       1
# 6            7       7
# 7            1       1
# 8            7       6
# 9            7       5
# 10           1       1
# 11           1       1
# 12           3       1
# 13           7       6
# 14           5       2
# 15           6       6
# 16           4       3
# 17           7       6
# 18           7       4
# 19           7       5
# 20           4       4
# 21           1       1
# 22           3       2
# 23           6       6
# 24           7       3
# 25           6       5
# 26           7       5
# 27           4       4
# 28           7       7
# 29           7       5
# 30           6       6
# 31           1       2
# 32           7       7
# 33           1       1
# 34           4       3
# 35           4       3
# 36           6       5
# 37           1       1
# 38           4       4
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
target = qb_df["Round"]
target_names = ["1", "2", "3", "4", "5", "6", "7"]

# %%
data = qb_df.drop(columns=['Unnamed: 0', 'Year', 'Drafted', 'Draft_Outcome', 'Player', 'Height', 'Wt', '40YD', 'Vertical', 'BenchReps', 'Broad Jump', '3Cone', 'Shuttle', 'Round', 'Pick', 'Age', 'Team', 'All Pro', 'Pro Bowl', 'Games', 'Rush Attempts', 'Rush Yards', 'Rush TDs', 'Receptions', 'Receiving Yards', 'Receiving TDs', 'Tackles', 'Picks', 'Sacks'])
feature_names = data.columns
data.head()
# Out:
#        AV  Pass Completions  Pass Attempts  Pass Yards  Pass TDs  \
# Pos
# QB    2.0              70.0          152.0       585.0       1.0
# QB    9.0             286.0          500.0      3179.0      21.0
# QB   12.0             432.0          714.0      4853.0      31.0
# QB   55.0            1632.0         2471.0     17823.0     102.0
# QB    0.0               6.0           16.0        69.0       0.0
#
#      Interceptions
# Pos
# QB             7.0
# QB            14.0
# QB            23.0
# QB            64.0
# QB             1.0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
train_scores = []
test_scores = []
for k in range(1, 20, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    train_score = knn.score(X_train, y_train)
    test_score = knn.score(X_test, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(f"k: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")
    
    
plt.plot(range(1, 20, 2), train_scores, marker='o')
plt.plot(range(1, 20, 2), test_scores, marker="x")
plt.xlabel("k neighbors")
plt.ylabel("Testing accuracy Score")
plt.show()
# Out:
# k: 1, Train/Test Score: 0.849/0.140
# k: 3, Train/Test Score: 0.532/0.233
# k: 5, Train/Test Score: 0.468/0.209
# k: 7, Train/Test Score: 0.452/0.233
# k: 9, Train/Test Score: 0.444/0.209
# k: 11, Train/Test Score: 0.452/0.233
# k: 13, Train/Test Score: 0.460/0.233
# k: 15, Train/Test Score: 0.452/0.233
# k: 17, Train/Test Score: 0.437/0.233
# k: 19, Train/Test Score: 0.429/0.256

# %%
knn = KNeighborsClassifier(n_neighbors=13)
knn.fit(X_train, y_train)
print('k=13 Test Acc: %.3f' % knn.score(X_test, y_test))
# Out:
# k=13 Test Acc: 0.233

# %%
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
print('Test Acc: %.3f' % model.score(X_test, y_test))
# Out:
# Test Acc: 0.279

# %%
from sklearn.metrics import classification_report
predictions = model.predict(X_test)
print(classification_report(y_test, predictions,
                            target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#           1       0.44      0.57      0.50         7
#           2       0.20      0.10      0.13        10
#           3       0.33      0.25      0.29         4
#           4       0.00      0.00      0.00         4
#           5       0.50      0.33      0.40         6
#           6       0.17      0.14      0.15         7
#           7       0.23      0.60      0.33         5
#
# avg / total       0.27      0.28      0.26        43
# /Users/uknowconorhealy/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 7, does not match size of target_names, 8
#   .format(len(labels), len(target_names))

# %%
from sklearn import tree
