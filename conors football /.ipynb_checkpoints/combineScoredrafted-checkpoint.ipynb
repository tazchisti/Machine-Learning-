# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
Offense = pd.read_csv('offensiveNFL_Data.csv')
Offense.set_index("Pos", inplace=True)
Offense.head()
# Out:
#      Unnamed: 0  Year           Player  Height   Wt  40YD  Vertical  \
# Pos
# QB            0  2000     Spergon Wynn    75.0  229  4.91      34.0
# WR            1  2000   James Williams    71.0  180  4.59      36.0
# G             2  2000  Bobbie Williams    76.0  332  5.26      29.0
# RB            3  2000    Michael Wiley    71.0  193  4.50       0.0
# WR            4  2000        Dez White    73.0  218  4.62      37.5
#
#      BenchReps  Broad Jump  3Cone  ...  Interceptions Rush Attempts  \
# Pos                                ...
# QB         0.0       108.0   7.71  ...            7.0          11.0
# WR         0.0       123.0   7.22  ...            0.0           1.0
# G         28.0        97.0   7.78  ...            0.0           0.0
# RB         0.0         0.0   0.00  ...            0.0          80.0
# WR         0.0       124.0   6.91  ...            0.0           8.0
#
#      Rush Yards  Rush TDs  Receptions Receiving Yards  Receiving TDs  Tackles  \
# Pos
# ...

# %%
rb_df = Offense.loc["RB"]
rb_df
# Out:
#      Unnamed: 0  Year               Player  Height   Wt  40YD  Vertical  \
# Pos
# RB            3  2000        Michael Wiley    71.0  193  4.50       0.0
# RB           15  2000        Shyrone Stith    67.0  204  4.60      35.0
# RB           19  2000           Paul Smith    71.0  220  4.65       0.0
# RB           26  2000         J.R. Redmond    71.0  216  4.48      32.5
# RB           30  2000      Travis Prentice    73.0  225  4.50      37.0
# RB           36  2000          Chad Morton    68.0  182  4.50      36.0
# RB           38  2000         Sammy Morris    73.0  221  4.65      37.5
# RB           39  2000         Frank Moreau    73.0  231  4.57      36.0
# RB           40  2000       Rondell Mealey    73.0  212  4.69      33.0
# RB           45  2000          Jamal Lewis    73.0  240  4.58       0.0
# RB           49  2000        Curtis Keaton    70.0  214  4.41      41.5
# RB           51  2000         Thomas Jones    70.0  216  4.45       0.0
# ...

# %%
rb_df.to_csv("rb_df.csv", header=True, index=True)

# %%
X = rb_df[["Height", "WT", "40YD", "Vertical", "BenchReps", "3Cone", "Broad Jump", "Shuttle"]]
y = rb_df["Round"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-830f9d67b020> in <module>()
# ----> 1 X = rb_df[["Height", "WT", "40YD", "Vertical", "BenchReps", "3Cone", "Broad Jump", "Shuttle"]]
#       2 y = rb_df["Round"].values.reshape(-1, 1)
#       3 print(X.shape, y.shape)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2922                 key = list(key)
#    2923             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2924                                                    raise_missing=True)
#    2925
#    2926         # take() does not accept boolean indexers
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = model.predict(X_test_scaled)
model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), model.predict(X_train_scaled) - y_train_scaled, c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), model.predict(X_test_scaled) - y_test_scaled, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score


predicted = model.predict(X)


mse = mean_squared_error(y, predicted)
r2 = r2_score(y, predicted)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# Out:
# Mean Squared Error (MSE): 14586366.69177162
# R-squared (R2 ): -3742492.0575424302

# %%
model.score(X, y)
# Out:
# -3742492.0575424302

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.score(X_test, y_test)
# Out:
# 0.1202517473479714

# %%
X = rb_df.drop(columns=['Unnamed: 0', 'Year', 'Player', 'Height', 'Wt', '40YD', 'Vertical', 'BenchReps', 'Broad Jump', '3Cone', 'Shuttle', 'Drafted', 'Round', 'Pick', 'Age', 'Team', 'All Pro', 'Pro Bowl', 'Games', 'Pass Completions', 'Interceptions', 'Pass Attempts', 'Pass Yards', 'Pass TDs', 'Receptions', 'Receiving Yards', 'Receiving TDs', 'Tackles', 'Picks', 'Sacks'])
y = rb_df["Round"]
print(X.shape, y.shape)
# Out:
# (280, 4) (280,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.3
# Testing Data Score: 0.24285714285714285

# %%
predictions = classifier.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   [6. 7. 4. 1. 1. 6. 7. 7. 7. 3.]
# First 10 Actual labels: [4.0, 3.0, 3.0, 1.0, 7.0, 4.0, 5.0, 7.0, 6.0, 6.0]

# %%
pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
# Out:
#     Prediction  Actual
# 0          6.0     4.0
# 1          7.0     3.0
# 2          4.0     3.0
# 3          1.0     1.0
# 4          1.0     7.0
# 5          6.0     4.0
# 6          7.0     5.0
# 7          7.0     7.0
# 8          7.0     6.0
# 9          3.0     6.0
# 10         5.0     4.0
# 11         1.0     1.0
# 12         3.0     2.0
# 13         1.0     2.0
# 14         4.0     2.0
# 15         4.0     3.0
# 16         4.0     6.0
# 17         1.0     3.0
# 18         7.0     7.0
# 19         6.0     7.0
# 20         6.0     3.0
# 21         4.0     4.0
# 22         4.0     2.0
# 23         1.0     3.0
# 24         1.0     1.0
# 25         4.0     5.0
# 26         7.0     6.0
# 27         7.0     6.0
# 28         1.0     5.0
# 29         4.0     1.0
# ..         ...     ...
# 40         7.0     7.0
# 41         7.0     5.0
# 42         4.0     4.0
# 43         4.0     4.0
# 44         4.0     6.0
# 45         4.0     1.0
# 46         4.0     5.0
# 47         3.0     6.0
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
target = rb_df["Round"]
target_names = ["1", "2", "3", "4", "5", "6", "7", "0"]

# %%
data = rb_df.drop(columns=['Unnamed: 0', 'Year', 'Player', 'Height', 'Wt', '40YD', 'Vertical', 'BenchReps', 'Broad Jump', '3Cone', 'Shuttle', 'Drafted', 'Round', 'Pick', 'Age', 'Team', 'All Pro', 'Pro Bowl', 'Games', 'Pass Completions', 'Interceptions', 'Pass Attempts', 'Pass Yards', 'Pass TDs', 'Receptions', 'Receiving Yards', 'Receiving TDs', 'Tackles', 'Picks', 'Sacks'])
feature_names = data.columns
data.head()
# Out:
#       AV  Rush Attempts  Rush Yards  Rush TDs
# Pos
# RB   4.0           80.0       503.0       1.0
# RB   0.0           20.0        55.0       1.0
# RB   3.0           46.0       210.0       1.0
# RB   9.0          194.0       676.0       1.0
# RB   4.0          187.0       525.0       9.0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
train_scores = []
test_scores = []
for k in range(1, 20, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    train_score = knn.score(X_train, y_train)
    test_score = knn.score(X_test, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(f"k: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")
    
    
plt.plot(range(1, 20, 2), train_scores, marker='o')
plt.plot(range(1, 20, 2), test_scores, marker="x")
plt.xlabel("k neighbors")
plt.ylabel("Testing accuracy Score")
plt.show()
# Out:
# k: 1, Train/Test Score: 0.948/0.186
# k: 3, Train/Test Score: 0.562/0.171
# k: 5, Train/Test Score: 0.448/0.171
# k: 7, Train/Test Score: 0.400/0.200
# k: 9, Train/Test Score: 0.429/0.200
# k: 11, Train/Test Score: 0.429/0.229
# k: 13, Train/Test Score: 0.395/0.214
# k: 15, Train/Test Score: 0.376/0.229
# k: 17, Train/Test Score: 0.352/0.229
# k: 19, Train/Test Score: 0.357/0.243

# %%
knn = KNeighborsClassifier(n_neighbors=13)
knn.fit(X_train, y_train)
print('k=13 Test Acc: %.3f' % knn.score(X_test, y_test))
# Out:
# k=13 Test Acc: 0.214

# %%
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
print('Test Acc: %.3f' % model.score(X_test, y_test))
# Out:
# Test Acc: 0.186

# %%
from sklearn.metrics import classification_report
predictions = model.predict(X_test)
print(classification_report(y_test, predictions,
                            target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#           1       0.41      0.78      0.54         9
#           2       0.00      0.00      0.00         9
#           3       0.10      0.10      0.10        10
#           4       0.00      0.00      0.00        14
#           5       0.00      0.00      0.00         7
#           6       0.33      0.08      0.13        12
#           7       0.18      0.44      0.26         9
#
# avg / total       0.15      0.19      0.14        70
# /Users/uknowconorhealy/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 7, does not match size of target_names, 8
#   .format(len(labels), len(target_names))
# /Users/uknowconorhealy/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
